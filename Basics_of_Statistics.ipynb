# %% [markdown]
# **1. Explain the different types of data (qualitative and quantitative) and provide examples of each. Discuss nominal, ordinal, interval, and ratio scales.**
#
# Data is generally classified into two primary types: qualitative (or categorical) and quantitative (or numerical).
#
# **Qualitative Data**
#
# Qualitative data describes attributes or characteristics and can be divided into two types:
#
# **Nominal:** This is data that can be categorized but has no intrinsic ordering.
#
# **Example:** Gender (Male, Female), hair color (Brown, Black, Blonde), and eye color (Blue, Green, Brown).
#
# **Ordinal:** This data also consists of categories, but these categories have a meaningful order.
#
# **Example:** Satisfaction level (Satisfied, Neutral, Dissatisfied), educational level (High School, Bachelor's, Master's), and rankings (1st, 2nd, 3rd).
#
# **Quantitative Data**
#
# Quantitative data represents numerical values and can be measured. There are two primary types:
#
# **Interval:** This scale has ordered categories that have a meaningful interval between them but lack a true zero point.
#
# **Example:** Temperature in Celsius or Fahrenheit (0°C is not the absence of temperature), IQ scores, and calendar years (2000, 2020, etc.).
#
# **Ratio:** This scale has ordered categories, meaningful intervals, and a true zero point, allowing for comparisons of absolute magnitudes.
#
# **Example:** Height (0 cm means no height), weight (0 kg means no weight), and income (0 dollars implies no income).
#
# ![image.png](data:image/png;base64,...)
#
# This classification allows for selecting appropriate analytical techniques for each type, enhancing data interpretation and analysis.

# %% [markdown]
# **2.  What are the measures of central tendency, and when should you use each? Discuss the mean, median, and mode with examples and situations where each is appropriate.**
#
# Measures of central tendency are statistical metrics that represent the center or typical value of a dataset. The primary measures are the mean, median, and mode, each of which is useful depending on the nature of the data and the analysis context.
#
# **1. Mean**
#
# The mean is the arithmetic average, calculated by summing all values and dividing by the number of values.
#
# **Formula:**
#
# **Mean**
#
#   Mean=
#   ∑X
#   /N
#
# where
# **𝑋**
# represents each value in the dataset, and
# **𝑁**
# is the total number of values.
#
# **Example:**
#
# For the dataset
# [
# 10
# ,
# 15
# ,
# 20
# ,
# 25
# ,
# 30
# ]
# [10,15,20,25,30], the mean is
#
# 10
# +
# 15
# +
# 20
# +
# 25
# +
# 30
# 5
# /
# 5
# =
# 20
#
# **When to use:**
#
# The mean is ideal when data is symmetrically distributed (no extreme outliers) and is often used with interval or ratio scales. It's commonly applied in contexts like average income or test scores, where each data point is valued equally.
#
# **Limitations:**
#
# The mean can be skewed by outliers. For instance, if one high income $1,000,000
#
# is   added to a dataset of typical incomes $30,000, $35,000, $40,000, the mean will increase significantly, potentially misrepresenting the "typical" income.
#
# **2. Median**
#
# The median is the middle value in an ordered dataset. If there is an odd number of values, the median is the middle one; if there’s an even number, it’s the average of the two central values.
#
# **Example:**
#
# For the dataset
#
# [10,15,20,25,30], the median is 20.
#
# For
# [10,15,20,25], the median is 15+20 = 17.5.
#
# **When to use:**
#
# The median is robust to outliers and is preferred when the dataset is skewed. It’s used frequently with ordinal, interval, or ratio data. For example, in income or property price data, where extreme values may skew the mean, the median provides a better central measure.
#
# **Limitations:**
#
# The median may not capture the overall distribution well in symmetric datasets, where the mean might be more representative.
#
# **3. Mode**
#
# The mode is the most frequently occurring value(s) in a dataset. A dataset can have no mode, one mode (unimodal), or multiple modes (bimodal, multimodal).
#
# **Example:**
#
# For the dataset
#
# [10,15,15,20,25], the mode is **15**.
#
# For
# [10,10,20,20,30], it’s bimodal with modes **10** and **20**.
#
# **When to use:**
#
# The mode is useful for categorical data where it’s helpful to know the most common category. For instance, in survey responses about favorite colors (Red, Blue, Green), the mode will identify the most preferred color.
#
# **Limitations:**
#
# The mode doesn’t provide much information about data spread and may be less informative for continuous numerical data with no frequently repeating values.
#
# ![image.png](data:image/png;base64,...)
#
# Choosing the right measure depends on the data’s distribution and the analysis goals. The mean provides a precise average for balanced data, the median offers a robust center for skewed data, and the mode identifies the most common category in nominal datasets.

# %% [markdown]
# **3. Explain the concept of dispersion. How do variance and standard deviation measure the spread of data?**
#
# Dispersion is a statistical concept that describes the spread or variability of data points within a dataset. It indicates how much the values deviate from the central tendency (like the mean or median), helping us understand the consistency or variability in the data. If the data points are close to each other and the mean, the dispersion is low, meaning the dataset is more consistent. If they are spread out, the dispersion is high, indicating greater variability.
#
# **Key Measures of Dispersion**
#
# **1. Variance**
#
# Variance is a measure of how much each data point in a dataset varies from the mean. It’s calculated by averaging the squared differences between each data point and the mean.
#
# ![image.png](data:image/png;base64,...)
#
#
# where:
#
# 𝜎
# 2 is the population variance,
#
# 𝑋 represents each data point,
#
# 𝜇 is the mean of the dataset,
#
# 𝑁 is the number of data points.
#
# For a sample variance, the formula is slightly adjusted to:
#
# ![image.png](data:image/png;base64,...)
#
# where:
#
# 𝑠
# 2 is the sample variance,
#
# 𝑋
# ˉ is the sample mean,
#
# 𝑛 is the sample size.
#
# **Interpretation:**
#
# A larger variance indicates that data points are spread out more widely around the mean, while a smaller variance suggests that the data points are closer to the mean.
#
# **Example:**
#
# If two classes have the same average test score, but one class has a high variance and the other a low variance, the high-variance class would have scores that vary widely (e.g., some students scored very high or very low), while the low-variance class would have scores closer to the average.
#
# **2. Standard Deviation**
#
# The standard deviation is the square root of the variance and represents the average distance of each data point from the mean.
#
# ![image.png](data:image/png;base64,...)
#
#
# **Interpretation:**
#
# Like variance, a higher standard deviation indicates greater variability in the data, while a lower standard deviation shows that data points are closer to the mean. The standard deviation is in the same units as the data, which often makes it more interpretable than variance.
#
# **Example:**
#
# Suppose we are measuring the weights of a group of people. If the mean weight is 70 kg and the standard deviation is 5 kg, most people's weights will fall within 65–75 kg (within one standard deviation of the mean) in a normally distributed dataset.
#
# **Why Use Variance and Standard Deviation?**
#
# Variance and standard deviation help quantify the degree of spread in the data, adding context beyond the central tendency.
#
# Variance is useful in statistical calculations but can be difficult to interpret directly since it’s in squared units.
#
# Standard deviation is more interpretable in practical contexts because it’s in the same units as the original data, making it easier to understand the typical deviation from the mean.

# %% [markdown]
# **4. What is a box plot, and what can it tell you about the distribution of data?**
#
# A box plot (or box-and-whisker plot) is a graphical tool used to visually display the distribution, central tendency, and variability of a dataset. It provides a summary of data through its quartiles, which divide the data into four parts, and it highlights outliers, making it useful for understanding the spread and skewness of data.
#
# **Components of a Box Plot**
#
# **A typical box plot consists of the following elements:**
#
# **Median (Q2):**
#
# The middle value of the data, represented by a line inside the box. It indicates the central tendency.
#
# **Quartiles:**
#
# **First Quartile (Q1):**The 25th percentile, where 25% of the data points fall below this value.
#
# **Third Quartile (Q3):**The 75th percentile, where 75% of the data points fall below this value.
#
# The box itself spans from Q1 to Q3, showing the interquartile range (IQR), which is a measure of variability.
# IQR=Q3−Q1.
#
# **Whiskers:**
#
# Lines extending from the box to show the range of data within 1.5 times the IQR from Q1 and Q3. Points outside this range are considered potential outliers.
# Outliers: Individual data points outside the whiskers, often shown as dots or small circles. These points represent unusually high or low values.
#
# **Interpreting a Box Plot**
#
# **A box plot provides several insights about a dataset’s distribution:**
#
# **Central Tendency:**
#
# The median line inside the box shows where the center of the data lies.
# If the median is closer to Q1 or Q3, it suggests potential skewness.
#
# **Spread and Variability:**
#
# The IQR (width of the box) shows the spread of the middle 50% of the data. A wider box indicates more variability within this range.
#
# The whiskers indicate the range of most data points, providing insight into overall spread.
#
# **Skewness:**
#
# If the box plot is symmetric (the median is in the center, and whiskers are of equal length), the data may be symmetrically distributed.
#
# **If the median is closer to Q1 or Q3, or if one whisker is noticeably longer, it indicates skewness:**
#
# **Right-skewed (positive skew):**
# The median is closer to Q1, and the right whisker is longer.
#
# **Left-skewed (negative skew):**
# The median is closer to Q3, and the left whisker is longer.
#
# **Outliers:**
#
# Points outside the whiskers suggest outliers or unusually extreme values in the dataset. These may require further investigation, as they could indicate errors or unique phenomena in the data.
#
# **Example Interpretation**
#
# Imagine a box plot of test scores for a group of students:
#
# The median score is near the middle of the box, suggesting a relatively symmetric distribution.
#
# A long right whisker indicates a few students scored much higher than the rest, suggesting a right-skewed distribution.
#
# Several outliers above the right whisker show a small number of students with exceptional scores, which might require further analysis to see if these are due to special circumstances.

# %% [markdown]
# **5. Discuss the role of random sampling in making inferences about populations**
#
# Random sampling is a fundamental technique in statistics that allows us to make reliable inferences about a larger population by studying a smaller, randomly selected subset of that population. The goal of random sampling is to obtain a sample that accurately represents the population, ensuring that every member has an equal chance of being included. This reduces bias and helps statisticians draw conclusions that can be generalized to the entire population.
#
# **Key Roles of Random Sampling in Making Inferences
# Representativeness:**
#
# A well-conducted random sample tends to reflect the diversity and characteristics of the entire population. By selecting individuals or items randomly, we avoid systematic biases that could distort our analysis. For example, if a study on health outcomes randomly selects participants from all age groups, socioeconomic statuses, and geographic areas, its results will likely reflect the entire population’s health status.
#
# **Reducing Bias:**
#
# Random sampling minimizes selection bias, where certain members of the population may be more likely to be chosen than others. This is important because biased samples lead to biased inferences. For instance, in a survey about a community's preferences for public transportation improvements, only sampling people from a high-income neighborhood may exclude diverse viewpoints, skewing results.
#
# **Allowing Generalization:**
#
# The whole point of taking a random sample is to make inferences about a population without having to survey everyone. With a random sample, we can generalize findings to the entire population within a known level of confidence and precision. For instance, with random sampling, a polling organization can estimate the likely winner of an election without needing to survey every voter.
#
# **Enabling Statistical Inference:**
#
# Random samples allow for the application of statistical inference techniques, such as hypothesis testing and confidence intervals. These techniques rely on the assumption that the sample accurately reflects the population, which random sampling ensures. This enables us to make predictions and estimate population parameters (like the mean or proportion) based on sample statistics.
#
# **Calculating Sampling Error:**
#
# With random sampling, we can calculate the sampling error (the difference between the sample estimate and the true population parameter) and use it to create a margin of error. For example, a random sample of a population may estimate a population mean with a margin of error of ±3%. This provides a range within which the true population mean is likely to lie.
#
# **Example of Random Sampling in Practice**
#
# Imagine a researcher wants to estimate the average income of people in a large city.
#
# By using random sampling, they select a diverse group of residents, ensuring various demographics are represented.
#
# If this random sample yields an average income of $50,000 with a margin of error of ±$2,000, the researcher can confidently infer that the average income of the entire city lies between $48,000 and $52,000.
#
# **Challenges and Limitations of Random Sampling**
#
# **While random sampling is powerful, it has some limitations:**
#
# **Practicality:**In large populations, random sampling can be difficult or costly.
#
# **Non-response:**If a significant portion of the randomly selected sample doesn’t respond, the sample may become biased.
#
# **Sampling bias:**Ensuring true randomness can be challenging, especially if certain population groups are underrepresented.

# %% [markdown]
# **6.  Explain the concept of skewness and its types. How does skewness affect the interpretation of data?**
#
# Skewness is a statistical measure that describes the asymmetry of a dataset’s distribution around its mean. When data is perfectly symmetrical, the distribution has zero skewness. However, if the data is not symmetrical, skewness quantifies the extent and direction of this asymmetry.
#
# **Types of Skewness**
#
# **Positive Skew (Right Skew)**
#
# In a positively skewed distribution, the right tail (the larger values) is longer or fatter. Most of the data points are concentrated on the left side, with a few larger values stretching the distribution to the right.
#
# **Characteristics:**
#
# **Mean > Median > Mode**
#
# The mean is pulled in the direction of the tail, making it higher than the median and mode.
#
# **Example:** Income distribution is often positively skewed because while most people earn moderate incomes, a few people earn exceptionally high incomes, creating a long right tail.
#
# **Negative Skew (Left Skew)**
#
# In a negatively skewed distribution, the left tail (the smaller values) is longer or fatter. Most data points are on the right side, with a few smaller values stretching the distribution to the left.
#
# **Characteristics:**
#
# **Mean < Median < Mode**
#
# The mean is pulled toward the left tail, making it lower than the median and mode.
#
# **Example:** Test scores in an easy exam can be negatively skewed if most students score high but a few score exceptionally low, creating a left tail.
#
# **No Skew (Symmetrical Distribution)**
#
# In a perfectly symmetrical distribution (like the normal distribution), the data is evenly distributed around the mean, and both tails are identical.
#
# **Characteristics:**
#
# **Mean = Median = Mode**
#
# **Example:** Heights of people in a population often follow a near-symmetrical distribution, especially when separated by gender.
#
# **Measuring Skewness**
#
# **Skewness Coefficient:**
#
# This numerical value quantifies the degree of skewness:
#
# a) Positive values indicate right skewness.
#
# b) Negative values indicate left skewness.
#
# c) Zero (or close to zero) indicates symmetry.
#
# **How Skewness Affects Data Interpretation**
#
# **Impact on Measures of Central Tendency:**
#
# In skewed distributions, the mean is affected by extreme values and is pulled toward the longer tail. The median, being the middle value, is less influenced by outliers and often provides a better measure of central tendency in skewed data.
#
# **Choosing the Right Summary Statistics:**
#
# For positively skewed data, the median is typically more representative of the central location than the mean.
#
# For negatively skewed data, the same applies: the median is often a more accurate measure of the "typical" data point.
#
# **Interpreting Data Spread and Outliers:**
#
# Skewed distributions often suggest the presence of outliers on one side of the dataset, which may represent unique cases or errors that require further investigation.
#
# Skewness can indicate that the data may need transformation (like a log transformation) before certain statistical analyses, as many statistical tests assume normality (symmetry).
#
# **Decision-Making and Policy Implications:**
#
# Understanding skewness can impact decisions based on data. For example, if income data is positively skewed, reporting the median income rather than the mean may provide a more realistic view of what most people earn.
#
# **Example of Skewness Impact**
#
# **Consider a dataset of house prices in a city:**
#
# **Positive Skew:** A few extremely high-priced luxury homes can create a long right tail, increasing the mean more than the median.
#
# If the city government uses the mean to estimate typical housing costs, it might overestimate the affordability for most residents.

# %% [markdown]
# **7.  What is the interquartile range (IQR), and how is it used to detect outliers?**
#
# The interquartile range (IQR) is a measure of statistical dispersion that represents the range within which the middle 50% of data points lie. It is calculated as the difference between the third quartile (Q3) and the first quartile (Q1), which are the 75th and 25th percentiles, respectively.
#
# ![image.png](data:image/png;base64,...)
#
# **where:**
#
# Q1 (First Quartile) is the median of the lower half of the dataset, below the overall median.
#
# Q3 (Third Quartile) is the median of the upper half of the dataset, above the overall median.
#
# **Interpreting the IQR**
#
# The IQR provides a robust measure of spread that is less influenced by outliers than the range or standard deviation. A small IQR indicates that data points are close to the median, while a large IQR suggests greater variability within the middle 50% of the data.
#
# **Using the IQR to Detect Outliers**
#
# Outliers are values that fall significantly outside the typical range of a dataset. The IQR method for outlier detection identifies outliers based on their distance from Q1 and Q3, as follows:
#
# **Calculate the Lower Bound:**
#
# \text{Lower Bound} = Q1 - 1.5 \times \text{IQR} ] Any data point below this bound is considered an outlier.
#
# **Calculate the Upper Bound:**
#
# \text{Upper Bound} = Q3 + 1.5 \times \text{IQR} ] Any data point above this bound is considered an outlier.
#
# **Interpret the Results:**
#
# Values below the lower bound or above the upper bound are flagged as potential outliers. These values deviate significantly from the central 50% of the data, possibly due to errors, rare events, or genuinely extreme cases.
#
# **Example of Outlier Detection Using IQR**
#
# **Consider a dataset of exam scores:**
#
# [45,50,50,55,60,70,75,80,85,95,100,105].
#
# **Find Q1 and Q3:**
#
# Q1 (25th percentile) = 55
#
# Q3 (75th percentile) = 95
#
# **Calculate the IQR:**
#
# \text{IQR} = Q3 - Q1 = 95 - 55 = 40 ]
#
# **Calculate the Bounds:**
#
# Lower Bound:
#
# Q1−1.5×IQR=55−1.5×40=−5
#
# Upper Bound:
#
# Q3+1.5×IQR=95+1.5×40=155
#
# **Identify Outliers:**
#
# Since all data points are between -5 and 155, there are no outliers in this dataset according to the IQR method.
#
# **Advantages of Using IQR for Outlier Detection**
#
# **Resistant to Skewness and Outliers:** Unlike the mean and standard deviation, the IQR is not affected by extreme values.
#
# **Robust Method:** Since it relies only on the middle 50% of data, it provides a more accurate detection method in skewed or non-normal distributions.
#
# **Practical Use Cases**
#
# **Quality Control:** Companies can use the IQR to flag unusual variations in product quality metrics.
#
# **Finance:** In stock price analysis, IQR can help detect unusual price movements.
#
# **Survey Analysis:** In survey data, the IQR can help identify extreme responses that may skew the results.

# %% [markdown]
# **8. Discuss the conditions under which the binomial distribution is used.**
#
# The binomial distribution is a discrete probability distribution used to model the number of successes in a fixed number of independent trials, where each trial has only two possible outcomes (success or failure).
#
# The binomial distribution is particularly useful in situations where we want to determine the probability of a certain number of successes within a set number of trials.
#
# **Conditions for Using the Binomial Distribution**
#
# For a scenario to be accurately modeled by a binomial distribution, it must meet the following conditions:
#
# **Fixed Number of Trials (n):**
#
# The number of trials, denoted as
# 𝑛
#
# n, must be predetermined and fixed. Each trial is an experiment or observation with a binary outcome.
#
# **Example:** If you toss a coin 10 times,
#
# n=10 is fixed.
#
# **Two Possible Outcomes (Success and Failure):**
#
# Each trial must have exactly two possible outcomes: success (the outcome of interest) and failure (the other outcome). The probability of success is denoted by
# 𝑝
#
# p, and the probability of failure is
# 1−p.
#
# **Example:** In a coin toss, "heads" could be considered success and "tails" failure.
#
# **Constant Probability of Success (p):**
#
# The probability of success,
# 𝑝
#
# p, must remain constant across all trials. This means the likelihood of success in one trial does not change regardless of the outcomes of previous trials.
#
# **Example:** If the probability of getting heads on a coin toss is 0.5, then it must stay 0.5 for each of the 10 tosses.
#
# **Independence of Trials:**
#
# Each trial should be independent, meaning the outcome of one trial does not influence the outcome of another. Independence ensures that previous results do not affect the probability of future results.
#
# **Example:** If you roll a die, the result of one roll does not affect the result of another roll, making each roll an independent event.
#
# **Binomial Probability Formula**
#
# The probability of getting exactly
# k successes in
# n trials can be calculated using the binomial probability formula:
#
# where:
#
# (
# 𝑛/
# 𝑘
# )
# is the binomial coefficient, representing the number of ways to choose
# k successes out of
# n trials:
# (
# 𝑛/
# 𝑘
# )
# =
# k!(n−k)!,
#
# p is the probability of success on a single trial,
#
# (1−p) is the probability of failure on a single trial,
#
# X is the random variable representing the number of successes.
#
# **Examples of When to Use the Binomial Distribution**
#
# **Quality Control:**
#
# Suppose a factory produces light bulbs, and each bulb has a probability of 0.02 of being defective. If you randomly sample 50 bulbs, the binomial distribution can model the probability of finding a certain number of defective bulbs in that sample.
#
# **Clinical Trials:**
#
# In a clinical trial, if a new drug has a 70% chance of curing a disease, and 20 patients are treated, the binomial distribution can be used to calculate the probability that exactly 15 patients are cured.
#
# **Surveys and Polls:**
#
# If a survey shows that 60% of people approve of a new policy, the binomial distribution can estimate the probability of finding a certain number of people in favor of the policy when surveying a fixed number of individuals.
#
# **Sales and Marketing:**
#
# If a marketing email campaign has a 5% response rate, the binomial distribution can predict the likelihood of getting a specific number of responses out of 100 emails sent.
#
# **Limitations and When Not to Use the Binomial Distribution**
#
# **The binomial distribution is not suitable if:**
#
# The probability of success changes from trial to trial (e.g., if drawing items without replacement).
#
# The trials are not independent.
#
# There are more than two possible outcomes per trial (e.g., rolling a standard die, which has six possible outcomes).

# %% [markdown]
# **9. Explain the properties of the normal distribution and the empirical rule (68-95-99.7 rule).**
#
# The normal distribution, also known as the Gaussian distribution, is a continuous probability distribution that is symmetric and follows a bell-shaped curve. It is one of the most important probability distributions in statistics because it models many natural phenomena and forms the basis for many statistical tests and methods.
#
# **Properties of the Normal Distribution**
#
# **Symmetry:
#
#
# The normal distribution is symmetric about its mean. This means the left and right sides of the curve are mirror images, with half the data lying on each side of the mean.
#
# **Mean, Median, and Mode Are Equal:**
#
# In a perfectly normal distribution, the mean, median, and mode are all the same and located at the center of the distribution.
#
# **Bell-Shaped Curve:**
#
# The normal distribution forms a bell-shaped curve, with most of the data clustering around the mean. This shape reflects that values close to the mean are more frequent, while values far from the mean are less likely.
#
# **Defined by Mean (μ) and Standard Deviation (σ):**
#
# **The normal distribution is fully defined by two parameters:**
#
# **Mean (μ):** Determines the center or peak of the distribution.
#
# **Standard Deviation (σ):** Measures the spread or dispersion of the data. A larger standard deviation results in a wider, flatter curve, while a smaller standard deviation results in a narrower, steeper curve.
#
# **Asymptotic Behavior:**
#
# The tails of the normal distribution approach, but never touch, the horizontal axis. This means there is a non-zero probability of very extreme values, although they are rare.
#
# **Total Area Under the Curve is 1:**
#
# The area under the curve of a normal distribution is equal to 1, representing the total probability for all possible outcomes.
#
# The Empirical Rule (68-95-99.7 Rule)
#
# The Empirical Rule, also known as the 68-95-99.7 Rule, describes how data is distributed in a normal distribution in terms of standard deviations from the mean. This rule is extremely useful for quickly estimating the spread of data in a normal distribution.
#
# **Approximately 68% of Data Within 1 Standard Deviation:**
#
# About 68% of the values in a normal distribution lie within one standard deviation from the mean (i.e., between
# μ−σ and
# μ+σ).
#
# **Example:** If the mean test score is 70 with a standard deviation of 10, about 68% of students scored between 60 and 80.
#
# **Approximately 95% of Data Within 2 Standard Deviations:**
#
# Around 95% of the data falls within two standard deviations from the mean (i.e., between
# μ−2σ and
# μ+2σ).
#
# **Example:** With a mean of 70 and standard deviation of 10, 95% of scores would fall between 50 and 90.
#
# **Approximately 99.7% of Data Within 3 Standard Deviations:**
#
# Nearly all (99.7%) of the values are found within three standard deviations from the mean (i.e., between
# μ−3σ and
# μ+3σ).
#
# **Example:** In our test score example, 99.7% of scores would be between 40 and 100.
#
# **Applications of the Empirical Rule**
#
# **The empirical rule is often used to:**
#
# Quickly estimate probabilities in a normal distribution.
#
# **Identify outliers:** Data points falling beyond three standard deviations (either above or below) are considered unusual or potential outliers.
#
# **Interpret variability:** The rule allows analysts to assess how spread out the data is around the mean, aiding in understanding consistency and reliability.
#
# **Example Using the Empirical Rule**
#
# **Suppose the weight of apples in an orchard follows a normal distribution with a mean weight of 150 grams and a standard deviation of 15 grams:**
#
# 68% of apples weigh between 135 grams (150 - 15) and 165 grams (150 + 15).
#
# 95% of apples weigh between 120 grams (150 - 2×15) and 180 grams (150 + 2×15).
#
# 99.7% of apples weigh between 105 grams (150 - 3×15) and 195 grams (150 + 3×15).

# %% [markdown]
# **10. Provide a real-life example of a Poisson process and calculate the probability for a specific event.**
#
#
# A Poisson process models events occurring randomly over a continuous interval (such as time, area, or space) where the events happen independently of each other at a constant average rate. The Poisson distribution is then used to determine the probability of a certain number of events occurring within a specific interval.
#
# **Real-Life Example of a Poisson Process**
#
# Let's consider the example of a customer service center that receives an average of 3 calls per minute.
#
# **We can use a Poisson process here, as:**
#
# The calls arrive randomly and independently.
#
# The average rate of calls per minute is constant (3 calls/minute).
#
# There’s no limit to the number of calls that could potentially occur in any given minute.
#
# **Question:** Calculate the Probability of Receiving Exactly 5 Calls in a Given Minute
#
# **Let:**
#
# λ=3: the average rate of calls per minute.
#
# k=5: the specific number of calls we want to calculate the probability for in a given minute.
#
# The probability mass function (PMF) of a Poisson distribution is given by:
#
# ![image.png](data:image/png;base64,...)
#
# where:
#
# e is the base of the natural logarithm (approximately equal to 2.71828),
#
# k! denotes the factorial of
# k,
#
# λ is the average rate of occurrence over the interval.
#
# **Calculations**
#
# **Plugging in the values:**
# ![image.png](data:image/png;base64,...)
#
# We can now solve this step-by-step.
#
# The probability of receiving exactly 5 calls in a given minute is approximately 0.1008 or 10.08%.
#
# This means there is a 10.08% chance that the customer service center will receive exactly 5 calls in one minute.

# %% [markdown]
# **11.  Explain what a random variable is and differentiate between discrete and continuous random variables.**
#
# A random variable is a numerical outcome of a random phenomenon. It is a function that assigns a numerical value to each outcome in a sample space of a random experiment. Random variables are crucial in statistics and probability theory because they allow us to quantify outcomes and analyze the likelihood of various results.
#
# **Types of Random Variables**
#
# Random variables are categorized into two main types: discrete random variables and continuous random variables.
#
# **1. Discrete Random Variables**
#
# **Definition:** A discrete random variable can take on a countable number of distinct values. This means that the values can be enumerated, and there are gaps between possible values.
#
# **Characteristics:**
#
# Each value has a specific probability associated with it.
#
# Discrete random variables often arise from counting processes.
#
# **Examples:**
#
# The number of heads obtained when flipping a coin multiple times (e.g., 0, 1, 2, ..., n).
#
# The number of students present in a classroom on a given day (e.g., 0, 1, 2, ..., N).
#
# The number of defective items in a batch of products.
#
# **Probability Mass Function (PMF):** The probability distribution of a discrete random variable is described by a probability mass function, which assigns probabilities to each possible value.
#
# **2. Continuous Random Variables**
#
# **Definition:** A continuous random variable can take on an infinite number of values within a given range. The possible values are uncountable and can include any value in an interval.
#
# **Characteristics:**
#
# The values are not isolated; they can take any value within a range (e.g., any real number).
#
# Continuous random variables often arise from measurements.
#
# **Examples:
#
# The height of students in a class (e.g., can be any value between, say, 150 cm and 200 cm).
#
# The time it takes to run a marathon (e.g., any value greater than zero).
# The temperature in a city at a given time.
#
# **Probability Density Function (PDF):** The probability distribution of a continuous random variable is described by a probability density function, which indicates the likelihood of the variable falling within a particular range. However, the probability of the variable taking on an exact value is zero; instead, probabilities are calculated over intervals.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **12. . Provide an example dataset, calculate both covariance and correlation, and interpret the results.**
#
# Let's consider a simple example dataset that contains information about the study hours and corresponding exam scores of students. This dataset will allow us to calculate both covariance and correlation to understand the relationship between study hours and exam scores.
#
#
# **Step 1: Calculate Covariance**
#
# Covariance measures how two random variables change together. A positive covariance indicates that as one variable increases, the other also tends to increase, while a negative covariance indicates that as one variable increases, the other tends to decrease.
#
# ![image.png](data:image/png;base64,...)
#
# where:
#
# 𝑋
# 𝑖 and
# 𝑌
# 𝑖 are the individual sample points,
#
# 𝑋
# ˉ
#   and
# 𝑌
# ˉ are the sample means of
# 𝑋 and
# 𝑌,
#
# 𝑛 is the number of data points.
#
# **Step 2: Calculate Correlation**
#
# Correlation quantifies the strength and direction of the linear relationship between two variables. The correlation coefficient
# 𝑟 is calculated using the formula:
#
# ![image.png](data:image/png;base64,...)
#
# where:
#
# 𝜎
# 𝑋 and
# 𝜎
# 𝑌
#  are the standard deviations of
# 𝑋 and
# 𝑌.
#
# Now, let's calculate both covariance and correlation for our dataset.
#
# **Results**
#
# **Covariance:**
# Cov(X,Y)=10.0
#
# **Correlation:**
# r=0.8
#
# **Interpretation**
#
# **Covariance:**
#
# The positive covariance of 10.0 indicates that there is a tendency for study hours and exam scores to increase together. In other words, as students study more hours, their exam scores tend to be higher. However, the magnitude of the covariance alone does not provide a clear measure of the strength of this relationship, as it depends on the units of the variables involved.
#
# **Correlation:**
#
# The correlation coefficient of 0.8 suggests a strong positive linear relationship between study hours and exam scores. This means that, generally, as the number of study hours increases, the exam scores increase as well. A correlation close to 1 indicates a strong linear relationship, while a correlation close to 0 indicates a weak relationship. A correlation of 0.8 implies that students who study more hours tend to perform better on exams.
