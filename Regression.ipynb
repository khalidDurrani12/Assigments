# %% [markdown]
# **1. What is Simple Linear Regression?**
#
# Simple Linear Regression is a statistical method used to model the relationship between two continuous variables:
#
# **Independent variable (X):** The predictor or explanatory variable.
#
# **Dependent variable (Y):** The response variable.
#
# It fits a straight line (regression line) to the data using the equation
# 𝑌
# =
# 𝑚
# 𝑋
# +
# 𝑐
# , where
# 𝑚 is the slope and
# 𝑐 is the intercept.

# %% [markdown]
# **2.What are the Key Assumptions of Simple Linear Regression?**
#
# For accurate results, Simple Linear Regression relies on these assumptions:
#
# **Linearity:** The relationship between
# 𝑋 and
# 𝑌 is linear.
#
# **Independence:** The residuals (errors) are independent.
#
# **Homoscedasticity:** The variance of residuals is constant across all levels of
# 𝑋.
#
# **Normality:** The residuals are normally distributed.
#
# **No Multicollinearity:** Since there's only one predictor, this assumption automatically holds.

# %% [markdown]
# **3. What does the coefficient
# 𝑚 represent in the equation
# 𝑌
# =
# 𝑚
# 𝑋
# +
# 𝑐?**
#
# The slope
# 𝑚:
#
# Represents the rate of change in
# 𝑌
# Y for a one-unit increase in
# 𝑋.
#
# Indicates the strength and direction of the relationship:
#
# * **Positive 𝑚:** 𝑌 increases as
# 𝑋 increases.
#
# * **Negative 𝑚:** 𝑌 decreases as
# 𝑋 increases.

# %% [markdown]
# **4. What does the intercept
# 𝑐
# c represent in the equation
# 𝑌
# =
# 𝑚
# 𝑋
# +
# 𝑐?**
#
# **The intercept
# 𝑐:**
#
# Represents the value of
# 𝑌 when
# 𝑋
# =
# 0.
#
# It is where the regression line crosses the
# 𝑌-axis.

# %% [markdown]
# **5. How do we calculate the slope
# 𝑚
# m in Simple Linear Regression?**
#
# The slope
# 𝑚 is calculated using the formula:
#
# ![image.png](data:image/png;base64,...)
#
# Where:
#
# * Cov
# (
# 𝑋
# ,
# 𝑌
# ) is the covariance between
# 𝑋 and
# 𝑌.
#
# * Var
# (
# 𝑋
# ) is the variance of
# 𝑋.
#
# Alternatively, using summations:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **6. What is the purpose of the least squares method in Simple Linear Regression?**
#
# The least squares method minimizes the sum of squared residuals (errors):
#
# ![image.png](data:image/png;base64,...)
#
# **Purpose:**
#
# * Find the line that best fits the data.
#
# * Ensure the sum of squared differences between observed and predicted values is as small as possible.

# %% [markdown]
# **7. How is the coefficient of determination (
# 𝑅
# 2 interpreted in Simple Linear Regression?**
#
# * 𝑅
# 2: Measures how well the regression line explains the variability in the dependent variable.
#
# ![image.png](data:image/png;base64,...)
#
# Where:
#
# * **SS
# residual:** Sum of squared residuals.
#
# * **SS
# total:** Total sum of squares.
#
# **Interpretation:**
#
# * 𝑅2
# =: Perfect fit (100% of variability in
# 𝑌 is explained by
# 𝑋.
#
# * 𝑅2 = 0: No relationship between
# 𝑋 and 𝑌.

# %% [markdown]
# **8. What is Multiple Linear Regression?**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **9. What is the main difference between Simple and Multiple Linear Regression?**
#
# * **Simple Linear Regression:** Models the relationship between
# 𝑌 and one predictor (
# 𝑋.
# * **Multiple Linear Regression:** Models the relationship between
# 𝑌 and two or more predictors (
# 𝑋
# 1
# ,
# 𝑋
# 2
# ,
# .
# .
# .
# ,
# 𝑋𝑘.

# %% [markdown]
# **10. Key Assumptions of Multiple Linear Regression**
#
# * **Linearity:** The relationship between
# 𝑌 and predictors is linear.
#
# * **Independence:** Residuals are independent.
#
# * **Homoscedasticity:** Constant variance of residuals.
#
# * **Normality:** Residuals are normally distributed.
#
# * **No Multicollinearity:** Predictors are not highly correlated.

# %% [markdown]
# **11. What is heteroscedasticity, and how does it affect the results of a Multiple Linear Regression model?**
#
# * **Heteroscedasticity** occurs when the variance of residuals (errors) is not constant across all levels of the independent variable(s).
#
# * **Effect on the model:**
#
#   1. Reduces the efficiency of coefficient estimates, leading to less reliable
# 𝑡-tests and 𝑝-values.
#   2. Undermines the validity of confidence intervals, making it harder to trust hypothesis tests.
#
#   3. Potentially leads to biased or inefficient regression results.

# %% [markdown]
# **12. How can you improve a Multiple Linear Regression model with high multicollinearity?**
#
# * **Multicollinearity** occurs when independent variables are highly correlated.
#
# * **To address it:**
#
#   1. **Remove highly correlated variables:** Use correlation matrices or VIF (Variance Inflation Factor) to identify problematic variables.
#
#   2. **Combine variables:** Create composite or principal components (PCA) to reduce dimensionality.
#
#   3. **Regularization techniques:** Use Ridge Regression or Lasso Regression to shrink coefficients of collinear variables.
#
#   4. **Increase sample size:** Larger datasets can mitigate the impact of multicollinearity.

# %% [markdown]
# **13. What are some common techniques for transforming categorical variables for use in regression models?**
#
# * **One-hot encoding:** Converts categories into binary columns (e.g., using pandas get_dummies).
#
# * **Label encoding:** Assigns numerical labels to categories (e.g., 0, 1, 2).
#
# * **Binary encoding:** Combines label encoding with binary conversion for high-cardinality variables.
#
# * **Frequency encoding:** Replaces categories with their frequency of occurrence.
#
# * **Target encoding:** Replaces categories with their mean target value (used cautiously in cross-validation).

# %% [markdown]
# **14. What is the role of interaction terms in Multiple Linear Regression?**
#
# * Interaction terms capture the combined effect of two (or more) independent variables on the dependent variable.
#
# * They account for scenarios where the relationship between
# 𝑋
# 1
# X and
# 𝑌 depends on the level of
# 𝑋
# 2.
#
# * **Example:** If
# 𝑌 is sales,
# 𝑋
# 1 is advertising, and
# 𝑋
# 2 is season, the term
# 𝑋
# 1
# ×
# 𝑋
# 2 shows how advertising’s impact varies by season.

# %% [markdown]
# **15. How can the interpretation of intercept differ between Simple and Multiple Linear Regression?**
#
# * **Simple Linear Regression:**
#
#   The intercept (
# 𝑐) represents the expected value of
# 𝑌 when
# 𝑋
# =0.
#
# * **Multiple Linear Regression:**
# The intercept (
# 𝛽
# 0
# ) represents the expected value of
# 𝑌 when all independent variables (
# 𝑋
# 1
# ,
# 𝑋
# 2
# ,
# …
# ,
# 𝑋
# 𝑘) are zero, which may or may not have a practical meaning depending on the variables.

# %% [markdown]
# **16. What is the significance of the slope in regression analysis, and how does it affect predictions?**
#
# * The slope (
# 𝛽
# 𝑖
# ) measures the change in
# 𝑌 for a one-unit change in
# 𝑋𝑖, assuming all other variables are held constant.
#
#
# * **Effect on predictions:**
#
#     * A higher slope means
# 𝑌 is more sensitive to changes in
# 𝑋i.
#
#     * A  slope of zero implies no relationship between
# 𝑋𝑖 and
# 𝑌.

# %% [markdown]
# **17. How does the intercept in a regression model provide context for the relationship between variables?**
#
# * The intercept anchors the regression line on the
# 𝑌-axis.
#
# * It provides context by showing the expected value of
# 𝑌 when all predictors are zero.
#
# * If a zero value for predictors is unrealistic (e.g., age = 0), the intercept becomes a theoretical reference rather than a meaningful point.

# %% [markdown]
# **18. What are the limitations of using 𝑅2 as a sole measure of model performance?**
#
# 1. **Insensitive to overfitting:** A high
# 𝑅2 does not mean the model is accurate; it may overfit the data.
#
# 2. **Doesn’t reflect predictive power:** 𝑅2 only measures fit on the training data, not on unseen data.
#
# 3. **Ignores bias-variance tradeoff:** High
# 𝑅2 models may have high variance.
#
# 4. **Misleading with non-linear relationships:**
# 𝑅2 assumes linearity and may not represent model quality in non-linear regressions.

# %% [markdown]
# **19. How would you interpret a large standard error for a regression coefficient?**
#
# * **A large standard error indicates:**
#
#   1. High uncertainty in the estimate of the coefficient.
#
#   2. Potential multicollinearity or insufficient data to estimate the coefficient precisely.
#
# * **Implications:**
#
#   * The
# 𝑡-statistic (𝛽𝑖/𝑆𝐸) becomes smaller, leading to less reliable significance tests for the coefficient.

# %% [markdown]
# **20. How can heteroscedasticity be identified in residual plots, and why is it important to address it?**
#
# * **Identification:**
#
#   1. Residual vs. fitted value plot: Look for a "funnel" shape (widening or narrowing of residuals).
#
#   2. Breusch-Pagan or White’s test: Statistical tests for heteroscedasticity.
#
# * **Why address it:**
#
#   * Ensures valid hypothesis tests and confidence intervals.
#   * Improves efficiency of coefficient estimates.
#   * Prevents biased inferences and ensures accurate predictions.

# %% [markdown]
# **21. What does it mean if a Multiple Linear Regression model has a high 𝑅2 but low adjusted 𝑅2?**
#
# * **High 𝑅2:** Indicates the model explains a significant proportion of the variance in the dependent variable.
#
# * **Low adjusted 𝑅2:** Suggests that adding more predictors increases 𝑅2 without significantly improving the model’s explanatory power.
#
# * **Implication:** Some predictors may be irrelevant or redundant, leading to overfitting. Adjusted 𝑅2 penalizes for adding unnecessary variables.

# %% [markdown]
# **22. Why is it important to scale variables in Multiple Linear Regression?**
#
# * Scaling ensures variables are on comparable scales, which is crucial because:
#
#   1. **Interpretability:** Unscaled coefficients can be misleading when variables have different units.
#
#   2. **Numerical stability:** Scaled variables prevent large differences in magnitude, reducing computational errors.
#
#   3. **Regularization methods:** Techniques like Ridge or Lasso Regression require scaled data to assign appropriate penalties to coefficients.

# %% [markdown]
# **23. What is Polynomial Regression?**
#
# * Polynomial Regression models a non-linear relationship between the dependent and independent variable(s) by transforming predictors into higher-degree polynomials.
#
# * It extends the linear regression framework with terms like 𝑋2, 𝑋3, etc., while still being a type of regression.

# %% [markdown]
# **24. How does Polynomial Regression differ from Linear Regression?
#
# * **Linear Regression:** Assumes a straight-line relationship (𝑌=𝑚𝑋+𝑐).
#
# * **Polynomial Regression:** Models more complex, curved relationships using higher-order terms
# (e.g., 𝑌=𝑏0+𝑏1𝑋+𝑏2𝑋2).

# %% [markdown]
# **25. When is Polynomial Regression used?**
#
# * When the relationship between the independent and dependent variable(s) is non-linear.
#
# * **Common applications include:**
#
#   * Fitting non-linear trends in data.
#
#   * Modeling growth rates, natural processes, or phenomena with quadratic/cubic behavior.

# %% [markdown]
# **26. What is the general equation for Polynomial Regression?**
#
# **For a single variable:**
#
# ![image.png](data:image/png;base64,...)
#
# Where:
#
# * 𝑏0
# ,𝑏1,…
# ,𝑏𝑛 are coefficients.
#
# * 𝑛 is the degree of the polynomial.
# * 𝜖 represents the error term.

# %% [markdown]
# **27. Can Polynomial Regression be applied to multiple variables?**
#
# * Yes! Polynomial regression can be extended to multiple variables by including polynomial terms of each variable and their interactions.
#
# * Example for two variables
# 𝑋1 and 𝑋2:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **28. What are the limitations of Polynomial Regression?**
#
# * **1.Overfitting:** Higher-degree polynomials may fit the training data too closely, reducing generalization.
#
# * **2.Complexity:** Harder to interpret compared to linear regression.
#
# * **3.Extrapolation:** Predictions beyond the range of data can behave erratically.
#
# * **4.Collinearity:** Higher-order terms can lead to multicollinearity.
#
# * **5.Computational cost:** Increases with the degree of the polynomial and number of predictors.

# %% [markdown]
# **29. What methods can be used to evaluate model fit when selecting the degree of a polynomial?**
#
# **1. Cross-validation:** Assess performance on unseen data to prevent overfitting.
#
# **2. Adjusted 𝑅2:** Accounts for the number of predictors.
#
# **3. AIC/BIC (Akaike/Bayesian Information Criterion):** Penalize model complexity to balance fit and simplicity.
#
# **4. Residual analysis:** Inspect residual plots to check for randomness.
#
# **5. Visualization:** Compare fitted curves to actual data.

# %% [markdown]
# **30. Why is visualization important in Polynomial Regression?**
#
# * Helps identify whether the polynomial captures the underlying trend in the data.
#
# * Makes it easier to detect:
#
#   1.Overfitting (too complex curve).
#
#   2.Underfitting (curve too simple for the data).
#
#   3.Regions where the model fails to generalize.

# %%
#31. How is Polynomial Regression implemented in Python?

# Using numpy for polynomial terms:

import numpy as np
from sklearn.linear_model import LinearRegression

# Data
X = np.array([1, 2, 3, 4, 5]).reshape(-1, 1)
y = np.array([2, 6, 11, 18, 27])

# Generate polynomial features
X_poly = np.hstack((X, X**2))

# Fit regression model
model = LinearRegression()
model.fit(X_poly, y)
print(model.coef_, model.intercept_)
# Out:
# [1.05714286 0.85714286] 0.1999999999999975
